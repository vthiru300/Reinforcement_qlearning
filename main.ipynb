# %%
import pickle
from gridworld import *
from analyze import *

# %%
if __name__ == '__main__':
    #runtime = 100
    filename_state = 'state'
    filename_qtable = 'qtable'
    filename_results = 'results'
    number_of_robots = 2
    number_of_interestpoints = 2
    dimension = 4
    env = GridWorld(number_of_robots, number_of_interestpoints, dimension)

    number_of_episodes = 5000
    env.train(number_of_episodes)
    analyze_convergence()
    env.visualize_training(filename_state, number_of_episodes)
    #env.evaluate(filename_qtable)
    #env.visualize(filename_results)
    env.close()
    fig, axs = plt.subplots(2)
    fig.suptitle('Plot Steps and Reward Buffer')
    axs[0].plot(range(len(rew_buf)), rew_buf)
    axs[1].plot(range(len(steps)), steps)
    #plt.plot(range(len(rew_buf)),rew_buf)
    plt.show()
# Out:
# Robot ID = 0: Robot Starting Position = [3, 1]
# Robot ID = 1: Robot Starting Position = [1, 1]
# Interest Point ID = 0: Starting Position = [1, 1]
# Interest Point ID = 1: Starting Position = [0, 2]
# running on the CPU
#
# Step 1000
# Episode 49
# Avg Rew -92.22448979591837
# Epsilon 0.8142721362036324
#
# Step 2000
# Episode 91
# Avg Rew -90.71910112359551
# Epsilon 0.7486042836152874
#
# Step 3000
# Episode 132
# Avg Rew -79.89
# Epsilon 0.6896115086754854
#
# Step 4000
# Episode 164
# Avg Rew -100.73
# Epsilon 0.646817589939501
#
# Step 5000
# Episode 218
# Avg Rew -78.55
# Epsilon 0.580538533306706
#
# Step 6000
# Episode 271
# Avg Rew -46.57
# Epsilon 0.5220952470763096
#
# Step 7000
# Episode 314
# Avg Rew -47.82
# Epsilon 0.47903033346842655
#
# Step 8000
# Episode 361
# Avg Rew -57.17
# Epsilon 0.4360120133570491
#
# Step 9000
# Episode 395
# Avg Rew -66.47
# Epsilon 0.407321054322426
#
# Step 10000
# Episode 443
# Avg Rew -51.37
# Epsilon 0.37000095160688506
#
# Step 11000
# Episode 475
# Avg Rew -64.03
# Epsilon 0.3470405014750226
#
# Step 12000
# Episode 520
# Avg Rew -50.56
# Epsilon 0.31714255461809093
#
# Step 13000
# Episode 562
# Avg Rew -46.32
# Epsilon 0.29156625205265024
#
# Step 14000
# Episode 609
# Avg Rew -42.65
# Epsilon 0.2653827528290002
#
# Step 15000
# Episode 669
# Avg Rew -22.6
# Epsilon 0.23534510621268118
#
# Step 16000
# Episode 723
# Avg Rew -23.86
# Epsilon 0.21122941754629784
#
# Step 17000
# Episode 784
# Avg Rew -22.79
# Epsilon 0.18694653499290784
#
# Step 18000
# Episode 853
# Avg Rew -15.38
# Epsilon 0.16282638045851483
#
# Step 19000
# Episode 922
# Avg Rew -6.93
# Epsilon 0.14181824859298311
#
# Step 20000
# Episode 969
# Avg Rew -13.1
# Epsilon 0.12908255653057227
#
# Step 21000
# Episode 1027
# Avg Rew -18.41
# Epsilon 0.11493146772198493
#
# Step 22000
# Episode 1094
# Avg Rew -9.41
# Epsilon 0.10050443329731377
#
# Step 23000
# Episode 1149
# Avg Rew -11.66
# Epsilon 0.09002538553426817
#
# Step 24000
# Episode 1214
# Avg Rew -8.29
# Epsilon 0.07904059003713867
#
# Step 25000
# Episode 1259
# Avg Rew -14.35
# Epsilon 0.07223115035955976
#
# Step 26000
# Episode 1307
# Avg Rew -19.16
# Epsilon 0.06561309336968801
#
# Step 27000
# Episode 1363
# Avg Rew -13.17
# Epsilon 0.05865443090664389
#
# Step 28000
# Episode 1412
# Avg Rew -14.89
# Epsilon 0.05317375723910183
#
# Step 29000
# Episode 1457
# Avg Rew -20.27
# Epsilon 0.0485927755918272
#
# Step 30000
# Episode 1520
# Avg Rew -11.86
# Epsilon 0.0428347076870136
#
# Step 31000
# Episode 1566
# Avg Rew -11.39
# Epsilon 0.03906615840892011
#
# Step 32000
# Episode 1639
# Avg Rew 0.09
# Epsilon 0.03375438664099096
#
# Step 33000
# Episode 1706
# Avg Rew -1.92
# Epsilon 0.0295172903286806
#
# Step 34000
# Episode 1769
# Avg Rew -2.05
# Epsilon 0.02601959833622677
#
# Step 35000
# Episode 1823
# Avg Rew -8.01
# Epsilon 0.023353383844671827
#
# Step 36000
# Episode 1876
# Avg Rew -10.05
# Epsilon 0.021002379702520616
#
# Step 37000
# Episode 1963
# Avg Rew 1.88
# Epsilon 0.017645159881983747
#
# Step 38000
# Episode 2020
# Avg Rew 0.5
# Epsilon 0.01574223717349395
#
# Step 39000
# Episode 2077
# Avg Rew -7.78
# Epsilon 0.014044533055184424
#
# Step 40000
# Episode 2142
# Avg Rew -2.5
# Epsilon 0.012330835051579081
#
# Step 41000
# Episode 2190
# Avg Rew -7.84
# Epsilon 0.011201043144654846
#
# Step 42000
# Episode 2243
# Avg Rew -11.26
# Epsilon 0.010073425022816527
#
# Step 43000
# Episode 2295
# Avg Rew -7.51
# Epsilon 0.009077480094449248
#
# Step 44000
# Episode 2349
# Avg Rew -8.3
# Epsilon 0.008147315506131016
#
# Step 45000
# Episode 2409
# Avg Rew -5.74
# Epsilon 0.00722515239855895
#
# Step 46000
# Episode 2475
# Avg Rew 0.11
# Epsilon 0.006330860397771021
#
# Step 47000
# Episode 2512
# Avg Rew -6.46
# Epsilon 0.005878855216726466
#
# Step 48000
# Episode 2554
# Avg Rew -17.87
# Epsilon 0.005404748612072032
#
# Step 49000
# Episode 2612
# Avg Rew -9.04
# Epsilon 0.004812235729981679
#
# Step 50000
# Episode 2680
# Avg Rew -2.94
# Epsilon 0.004199752534724593
#
# Step 51000
# Episode 2739
# Avg Rew -3.59
# Epsilon 0.0037318625257097577
#
# Step 52000
# Episode 2803
# Avg Rew -2.42
# Epsilon 0.0032830710325362847
#
# Step 53000
# Episode 2881
# Avg Rew 1.35
# Epsilon 0.002808422861265344
#
# Step 54000
# Episode 2950
# Avg Rew 2.26
# Epsilon 0.0025
#
# Step 55000
# Episode 3019
# Avg Rew 1.11
# Epsilon 0.0025
#
# Step 56000
# Episode 3086
# Avg Rew 1.26
# Epsilon 0.0025
#
# Step 57000
# Episode 3157
# Avg Rew 0.99
# Epsilon 0.0025
#
# Step 58000
# Episode 3225
# Avg Rew 0.34
# Epsilon 0.0025
#
# Step 59000
# Episode 3288
# Avg Rew 2.56
# Epsilon 0.0025
#
# Step 60000
# Episode 3349
# Avg Rew -0.86
# Epsilon 0.0025
#
# Step 61000
# Episode 3411
# Avg Rew 2.77
# Epsilon 0.0025
#
# Step 62000
# Episode 3467
# Avg Rew -1.73
# Epsilon 0.0025
#
# Step 63000
# Episode 3541
# Avg Rew 4.49
# Epsilon 0.0025
#
# Step 64000
# Episode 3588
# Avg Rew -4.51
# Epsilon 0.0025
#
# Step 65000
# Episode 3654
# Avg Rew -0.62
# Epsilon 0.0025
#
# Step 66000
# Episode 3732
# Avg Rew 3.0
# Epsilon 0.0025
#
# Step 67000
# Episode 3807
# Avg Rew 1.03
# Epsilon 0.0025
#
# Step 68000
# Episode 3869
# Avg Rew 1.68
# Epsilon 0.0025
#
# Step 69000
# Episode 3949
# Avg Rew -1.01
# Epsilon 0.0025
#
# Step 70000
# Episode 4021
# Avg Rew 3.55
# Epsilon 0.0025
#
# Step 71000
# Episode 4094
# Avg Rew -2.17
# Epsilon 0.0025
#
# Step 72000
# Episode 4204
# Avg Rew 11.55
# Epsilon 0.0025
#
# Step 73000
# Episode 4295
# Avg Rew 7.62
# Epsilon 0.0025
#
# Step 74000
# Episode 4381
# Avg Rew 3.9
# Epsilon 0.0025
#
# Step 75000
# Episode 4454
# Avg Rew 1.54
# Epsilon 0.0025
#
# Step 76000
# Episode 4529
# Avg Rew 0.93
# Epsilon 0.0025
#
# Step 77000
# Episode 4585
# Avg Rew -2.06
# Epsilon 0.0025
#
# Step 78000
# Episode 4643
# Avg Rew -7.13
# Epsilon 0.0025
#
# Step 79000
# Episode 4715
# Avg Rew -0.84
# Epsilon 0.0025
#
# Step 80000
# Episode 4797
# Avg Rew 2.97
# Epsilon 0.0025
#
# Step 81000
# Episode 4889
# Avg Rew 5.86
# Epsilon 0.0025
#
# Step 82000
# Episode 4969
# Avg Rew 2.14
# Epsilon 0.0025

# %% [markdown]
# # Final Comments
# We can conclude from the above plots that the number of rewards keeps rising and essentially stays the same after a few episodes. Inconsistencies exist in the rewards between related episodes. 2. After each episode, the steps required to reach the interest point get progressively shorter, however there may be some variation. 3. The algorithm converges at a faster pace when the learning rate and discount factor are high and low, respectively. This results in fewer steps being needed and higher rewards. While the method takes longer to converge when the learning rate and discount rate are low and high, necessitating more steps and fewer rewards.
